# %% [markdown]
# ---
# ---
# # Loading Dataset & Modules

# %% [markdown]
# Modules

# %%
import pandas as pd

# %% [markdown]
# Loading Data

# %%
xls = pd.ExcelFile('Healthcare_dataset.xlsx')
df1 = pd.read_excel(xls, 'Feature Description')
df2 = pd.read_excel(xls, 'Dataset')

# %% [markdown]
# Dataset Sheet 1/2

# %%
df1
# Out:
#                       Bucket                             Variable  \
# 0              Unique Row Id                           Patient ID
# 1            Target Variable                     Persistency_Flag
# 2               Demographics                                  Age
# 3                        NaN                                 Race
# 4                        NaN                               Region
# 5                        NaN                            Ethnicity
# 6                        NaN                               Gender
# 7                        NaN                        IDN Indicator
# 8        Provider Attributes            NTM - Physician Specialty
# 9           Clinical Factors                       NTM - T-Score
# 10                       NaN                   Change in T Score
# 11                       NaN                   NTM - Risk Segment
# 12                       NaN               Change in Risk Segment
# 13                       NaN          NTM - Multiple Risk Factors
# 14                       NaN            NTM - Dexa Scan Frequency
# 15                       NaN              NTM - Dexa Scan Recency
# 16                       NaN                  Dexa During Therapy
# 17                       NaN     NTM - Fragility Fracture Recency
# 18                       NaN    Fragility Fracture During Therapy
# 19                       NaN         NTM - Glucocorticoid Recency
# 20                       NaN  Glucocorticoid Usage During Therapy
# 21  Disease/Treatment Factor          NTM - Injectable Experience
# 22                       NaN                   NTM - Risk Factors
# 23                       NaN                   NTM - Comorbidity
# 24                       NaN                   NTM - Concomitancy
# 25                       NaN                            Adherence
#
#                                  Variable Description
# 0                           Unique ID of each patient
# 1   Flag indicating if a patient was persistent or...
# 2             Age of the patient during their therapy
# 3          Race of the patient from the patient table
# 4        Region of the patient from the patient table
# 5     Ethnicity of the patient from the patient table
# 6        Gender of the patient from the patient table
# 7              Flag indicating patients mapped to IDN
# 8     Specialty of the HCP that prescribed the NTM Rx
# 9   T Score of the patient at the time of the NTM ...
# 10  Change in Tscore before starting with any ther...
# 11  Risk Segment of the patient at the time of the...
# 12  Change in Risk Segment before starting with an...
# 13  Flag indicating if  patient falls under multip...
# 14  Number of DEXA scans taken prior to the first ...
# 15  Flag indicating the presence of Dexa Scan befo...
# 16  Flag indicating if the patient had a Dexa Scan...
# 17  Flag indicating if the patient had a recent fr...
# 18  Flag indicating if the patient had fragility f...
# 19  Flag indicating usage of Glucocorticoids (>=7....
# 20  Flag indicating if the patient had a Glucocort...
# 21  Flag indicating any injectable drug usage in t...
# 22  Risk Factors that the patient is falling into....
# 23  Comorbidities are divided into two main catego...
# 24  Concomitant drugs recorded prior to starting w...
# 25                        Adherence for the therapies

# %% [markdown]
# Dataset Sheet 2/2

# %%
df2.head(2)
# Out:
#   Ptid Persistency_Flag Gender       Race     Ethnicity Region Age_Bucket  \
# 0   P1       Persistent   Male  Caucasian  Not Hispanic   West        >75
# 1   P2   Non-Persistent   Male      Asian  Not Hispanic   West      55-65
#
#          Ntm_Speciality Ntm_Specialist_Flag      Ntm_Speciality_Bucket  ...  \
# 0  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown  ...
# 1  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown  ...
#
#   Risk_Family_History_Of_Osteoporosis Risk_Low_Calcium_Intake  \
# 0                                   N                       N
# 1                                   N                       N
#
#    Risk_Vitamin_D_Insufficiency Risk_Poor_Health_Frailty  \
# 0                             N                        N
# 1                             N                        N
#
#   Risk_Excessive_Thinness Risk_Hysterectomy_Oophorectomy  \
# 0                       N                              N
# 1                       N                              N
#
#   Risk_Estrogen_Deficiency Risk_Immobilization Risk_Recurring_Falls  \
# 0                        N                   N                    N
# 1                        N                   N                    N
#
#   Count_Of_Risks
# 0              0
# 1              0
#
# [2 rows x 69 columns]

# %% [markdown]
# ---
# ---
# # Problem Understanding

# %% [markdown]
# Aim:
# * Understanding Persistency of the drug by using physician prescriptions.
# * Automate this process of identification.
#
# Methodology:
# * Gather insights from factors
# * Use ML techniques to classify the dataset

# %% [markdown]
# ---
# ---
# # Preprocess Part 0
# ## `Data Understanding`
# ### `Management of Data`

# %% [markdown]
# ## Organizing Data
# `Dataset`, df2, consists of 69 columns which have 6 main parts according to `Feature Description`,df1.
#
# ID, Target, Demographics, Provider, Clinical, Disease

# %% [markdown]
# ---
# Unique Row Id

# %%
# Patient ID
p_df = df2.iloc[:,0]

# %%
ID = pd.concat([p_df], axis = 1 ) 
ID.head()
# Out:
#   Ptid
# 0   P1
# 1   P2
# 2   P3
# 3   P4
# 4   P5

# %% [markdown]
# ---
# ### Target Variable

# %%
# Target 
t_df = df2.iloc[:,1]

# %%
Target = pd.concat([t_df], axis = 1 ) 
Target.head()
# Out:
#   Persistency_Flag
# 0       Persistent
# 1   Non-Persistent
# 2   Non-Persistent
# 3   Non-Persistent
# 4   Non-Persistent

# %% [markdown]
# ---
# ### Demographics

# %%
# Demographics
d_df = df2.loc[:, ['Age_Bucket', 'Race', 'Region', 'Gender', 'Ethnicity', 'Idn_Indicator' ] ]

# %%
Demographics = pd.concat([d_df], axis = 1 ) 
Demographics.head()
# Out:
#   Age_Bucket           Race   Region  Gender     Ethnicity Idn_Indicator
# 0        >75      Caucasian     West    Male  Not Hispanic             N
# 1      55-65          Asian     West    Male  Not Hispanic             N
# 2      65-75  Other/Unknown  Midwest  Female      Hispanic             N
# 3        >75      Caucasian  Midwest  Female  Not Hispanic             N
# 4        >75      Caucasian  Midwest  Female  Not Hispanic             N

# %% [markdown]
# ---
# ### Provider Attributes

# %%
# Provider Attributes
p_df = df2.loc[:,[
     'Ntm_Speciality', 'Ntm_Specialist_Flag', 'Ntm_Speciality_Bucket' ] ]

# %%
Provider = p_df 
Provider.head()
# Out:
#          Ntm_Speciality Ntm_Specialist_Flag      Ntm_Speciality_Bucket
# 0  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown
# 1  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown
# 2  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown
# 3  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown
# 4  GENERAL PRACTITIONER              Others  OB/GYN/Others/PCP/Unknown

# %% [markdown]
# ---
# ### Clinical Factors
# `!!!`
# * `# NTM - Multiple Risk Factors` is investigated under Disease/Treatment Factors.
# * `NTM - Dexa Scan Recency` cannot be found in the raw data.

# %%
# NTM - T-Score 
ntm_t = df2.loc[:,[
    'Tscore_Bucket_Prior_Ntm','Tscore_Bucket_During_Rx'] ]  

# Change in T Score 
ct = df2.loc[:,[
    'Change_T_Score'] ] 

# NTM - Risk Segment
ntm_r = df2.loc[:,[
'Risk_Segment_Prior_Ntm', 'Risk_Segment_During_Rx' ] ]

# Change in Risk Segment
c_r = df2.loc[:,[
'Change_Risk_Segment' ] ] 

# NTM - Multiple Risk Factors


# NTM - Dexa Scan Frequency
ntm_d_f = df2.loc[:,[
'Dexa_Freq_During_Rx' ] ] 

# NTM - Dexa Scan Recency


# Dexa During Therapy
d_d = df2.loc[:,[
    'Dexa_During_Rx' ] ] 

# NTM - Fragility Fracture Recency
ntm_f = df2.loc[:,[
'Frag_Frac_Prior_Ntm'] ]  

# Fragility Fracture During Therapy
f_f = df2.loc[:,[
'Frag_Frac_During_Rx'] ]  

# NTM - Glucocorticoid Recency
ntm_glu = df2.loc[:,[
       'Gluco_Record_Prior_Ntm'] ] 
       
# Glucocorticoid Usage During Therapy
glu = df2.loc[:,[
'Gluco_Record_During_Rx'] ]

# %%
Clinical = pd.concat( [ntm_t,ct,ntm_r, c_r,ntm_d_f ,d_d,ntm_f,f_f, ntm_glu, glu], axis = 1 ) 
Clinical.head()
# Out:
#   Tscore_Bucket_Prior_Ntm Tscore_Bucket_During_Rx Change_T_Score  \
# 0                   >-2.5                  <=-2.5      No change
# 1                   >-2.5                 Unknown        Unknown
# 2                  <=-2.5                  <=-2.5      No change
# 3                   >-2.5                  <=-2.5      No change
# 4                  <=-2.5                 Unknown        Unknown
#
#   Risk_Segment_Prior_Ntm Risk_Segment_During_Rx Change_Risk_Segment  \
# 0                 VLR_LR                 VLR_LR             Unknown
# 1                 VLR_LR                Unknown             Unknown
# 2                 HR_VHR                 HR_VHR           No change
# 3                 HR_VHR                 HR_VHR           No change
# 4                 HR_VHR                Unknown             Unknown
#
#    Dexa_Freq_During_Rx Dexa_During_Rx Frag_Frac_Prior_Ntm Frag_Frac_During_Rx  \
# 0                    0              N                   N                   N
# 1                    0              N                   N                   N
# 2                    0              N                   N                   N
# 3                    0              N                   N                   N
# 4                    0              N                   N                   N
#
#   Gluco_Record_Prior_Ntm Gluco_Record_During_Rx
# 0                      N                      N
# 1                      N                      N
# 2                      N                      N
# 3                      N                      Y
# 4                      Y                      Y

# %% [markdown]
# ---
# ### Disease/Treatment Factor

# %%
# NTM - Injectable Experience 
ntm_i = df2.loc[:,[
    'Injectable_Experience_During_Rx'] ] 

# Risk Factors 
r_f = df2.loc[:,[ 
       #'Risk_Segment_Prior_Ntm', 'Risk_Segment_During_Rx','Change_Risk_Segment',
       
       'Risk_Type_1_Insulin_Dependent_Diabetes',
       'Risk_Osteogenesis_Imperfecta', 'Risk_Rheumatoid_Arthritis',
       'Risk_Untreated_Chronic_Hyperthyroidism',
       'Risk_Untreated_Chronic_Hypogonadism', 'Risk_Untreated_Early_Menopause',
       'Risk_Patient_Parent_Fractured_Their_Hip', 'Risk_Smoking_Tobacco',
       'Risk_Chronic_Malnutrition_Or_Malabsorption',
       'Risk_Chronic_Liver_Disease', 'Risk_Family_History_Of_Osteoporosis',
       'Risk_Low_Calcium_Intake', 'Risk_Vitamin_D_Insufficiency',
       'Risk_Poor_Health_Frailty', 'Risk_Excessive_Thinness',
       'Risk_Hysterectomy_Oophorectomy', 'Risk_Estrogen_Deficiency',
       'Risk_Immobilization', 'Risk_Recurring_Falls', 'Count_Of_Risks'] ] 
       
# NTM - Comorbidity  
ntm_com = df2.loc[:,[ 
       'Comorb_Encounter_For_Screening_For_Malignant_Neoplasms',
       'Comorb_Encounter_For_Immunization',
       'Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx',
       'Comorb_Vitamin_D_Deficiency',
       'Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified',
       'Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx',
       'Comorb_Long_Term_Current_Drug_Therapy', 'Comorb_Dorsalgia',
       'Comorb_Personal_History_Of_Other_Diseases_And_Conditions',
       'Comorb_Other_Disorders_Of_Bone_Density_And_Structure',
       'Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias',
       'Comorb_Osteoporosis_without_current_pathological_fracture',
       'Comorb_Personal_history_of_malignant_neoplasm',
       'Comorb_Gastro_esophageal_reflux_disease'  ] ] 

# NTM - Concomitancy
ntm_con = df2.loc[:,[ 
       'Concom_Cholesterol_And_Triglyceride_Regulating_Preparations',
       'Concom_Narcotics', 'Concom_Systemic_Corticosteroids_Plain',
       'Concom_Anti_Depressants_And_Mood_Stabilisers',
       'Concom_Fluoroquinolones', 'Concom_Cephalosporins',
       'Concom_Macrolides_And_Similar_Types',
       'Concom_Broad_Spectrum_Penicillins', 'Concom_Anaesthetics_General',
       'Concom_Viral_Vaccines' ]  ]  

# Adherence 
ad = df2.loc[:,[ 
       'Adherent_Flag'] ]

# %%
Disease = pd.concat( [ ntm_i,r_f ,ntm_com,ntm_con, ad ], axis =1 )
Disease.head()
# Out:
#   Injectable_Experience_During_Rx Risk_Type_1_Insulin_Dependent_Diabetes  \
# 0                               Y                                      N
# 1                               Y                                      N
# 2                               Y                                      N
# 3                               Y                                      N
# 4                               Y                                      N
#
#   Risk_Osteogenesis_Imperfecta Risk_Rheumatoid_Arthritis  \
# 0                            N                         N
# 1                            N                         N
# 2                            N                         N
# 3                            N                         N
# 4                            N                         N
#
#   Risk_Untreated_Chronic_Hyperthyroidism Risk_Untreated_Chronic_Hypogonadism  \
# 0                                      N                                   N
# 1                                      N                                   N
# 2                                      N                                   N
# 3                                      N                                   N
# 4                                      N                                   N
#
#   Risk_Untreated_Early_Menopause Risk_Patient_Parent_Fractured_Their_Hip  \
# 0                              N                                       N
# 1                              N                                       N
# 2                              N                                       Y
# 3                              N                                       N
# 4                              N                                       N
#
#   Risk_Smoking_Tobacco Risk_Chronic_Malnutrition_Or_Malabsorption  ...  \
# 0                    N                                          N  ...
# 1                    N                                          N  ...
# 2                    N                                          N  ...
# 3                    Y                                          N  ...
# 4                    Y                                          N  ...
#
#   Concom_Narcotics Concom_Systemic_Corticosteroids_Plain  \
# 0                N                                     N
# 1                N                                     N
# 2                N                                     N
# 3                Y                                     Y
# 4                Y                                     Y
#
#   Concom_Anti_Depressants_And_Mood_Stabilisers Concom_Fluoroquinolones  \
# 0                                            N                       N
# 1                                            N                       N
# 2                                            N                       N
# 3                                            N                       N
# 4                                            Y                       N
#
#   Concom_Cephalosporins Concom_Macrolides_And_Similar_Types  \
# 0                     N                                   N
# 1                     N                                   N
# 2                     N                                   N
# 3                     N                                   N
# 4                     N                                   N
#
#   Concom_Broad_Spectrum_Penicillins Concom_Anaesthetics_General  \
# 0                                 N                           N
# 1                                 N                           N
# 2                                 N                           N
# 3                                 N                           N
# 4                                 N                           N
#
#   Concom_Viral_Vaccines Adherent_Flag
# 0                     N      Adherent
# 1                     N      Adherent
# 2                     N      Adherent
# 3                     Y      Adherent
# 4                     N      Adherent
#
# [5 rows x 46 columns]

# %% [markdown]
# ---
# # Preprocess Part 0 Result
# ## Organized Data

# %% [markdown]
# `! Important Notes`
# * `# NTM - Multiple Risk Factors` is investigated under Disease/Treatment Factors.
# * `NTM - Dexa Scan Recency` cannot be found in the raw data.

# %%
df = pd.concat( [ID, Target, Demographics, Provider, Clinical, Disease],axis=1 )  
df.head()
# Out:
#   Ptid Persistency_Flag Age_Bucket           Race   Region  Gender  \
# 0   P1       Persistent        >75      Caucasian     West    Male
# 1   P2   Non-Persistent      55-65          Asian     West    Male
# 2   P3   Non-Persistent      65-75  Other/Unknown  Midwest  Female
# 3   P4   Non-Persistent        >75      Caucasian  Midwest  Female
# 4   P5   Non-Persistent        >75      Caucasian  Midwest  Female
#
#       Ethnicity Idn_Indicator        Ntm_Speciality Ntm_Specialist_Flag  ...  \
# 0  Not Hispanic             N  GENERAL PRACTITIONER              Others  ...
# 1  Not Hispanic             N  GENERAL PRACTITIONER              Others  ...
# 2      Hispanic             N  GENERAL PRACTITIONER              Others  ...
# 3  Not Hispanic             N  GENERAL PRACTITIONER              Others  ...
# 4  Not Hispanic             N  GENERAL PRACTITIONER              Others  ...
#
#   Concom_Narcotics Concom_Systemic_Corticosteroids_Plain  \
# 0                N                                     N
# 1                N                                     N
# 2                N                                     N
# 3                Y                                     Y
# 4                Y                                     Y
#
#   Concom_Anti_Depressants_And_Mood_Stabilisers Concom_Fluoroquinolones  \
# 0                                            N                       N
# 1                                            N                       N
# 2                                            N                       N
# 3                                            N                       N
# 4                                            Y                       N
#
#   Concom_Cephalosporins Concom_Macrolides_And_Similar_Types  \
# 0                     N                                   N
# 1                     N                                   N
# 2                     N                                   N
# 3                     N                                   N
# 4                     N                                   N
#
#   Concom_Broad_Spectrum_Penicillins  Concom_Anaesthetics_General  \
# 0                                 N                            N
# 1                                 N                            N
# 2                                 N                            N
# 3                                 N                            N
# 4                                 N                            N
#
#   Concom_Viral_Vaccines Adherent_Flag
# 0                     N      Adherent
# 1                     N      Adherent
# 2                     N      Adherent
# 3                     Y      Adherent
# 4                     N      Adherent
#
# [5 rows x 69 columns]

# %% [markdown]
# ---
# ---
# # Preprocess Part 1
# ## `Data Cleaning and Feature engineering`
# ### `Unique & Missing Values`

# %% [markdown]
# ---
# ## Preprocessing 1.0
#
# Modules
#
# Necessary Functions

# %% [markdown]
# Modules

# %%
from collections import defaultdict

from collections import Counter

# %% [markdown]
# Taking out Unique Variables

# %%
def uvc(data):
    temp = defaultdict() 
    for i in data:
        temp[i] = pd.unique(data[i])
    return temp

# %% [markdown]
# Creating Dataframe for Unique & NaN Values

# %%
def un(data, conf = 1):
    temp = data 
    u_temp = [] # Unique Values 
    n_temp = [] # Nan Values 

    for i in temp.columns:
        u_temp.append( len( pd.unique(temp[i])) ) 
        if conf == 0:
            n_temp.append( temp[i].isna().sum() ) 
        else:
            try:
                n_temp.append( dict(Counter(temp[i]))['NaN']  )
            except:
                n_temp.append(0)

    un_temp = pd.DataFrame(list(zip(u_temp, n_temp)),
                columns =['Unique Values', 'Nan Values'])
    un_temp = un_temp.T
    un_temp.columns = temp.columns

    # Sums
    sum_temp = [un_temp.loc['Unique Values'].sum() , un_temp.loc['Nan Values'].sum()] 
    s_temp = pd.DataFrame(sum_temp, columns=['Sum'], index= un_temp.index ) 

    # Sums without ID
    sum_temp = [un_temp.loc['Unique Values'].sum() , un_temp.loc['Nan Values'].sum()] 
    s_temp = pd.DataFrame(sum_temp, columns=['Sum'], index= un_temp.index ) 
    
    un_temp = pd.concat( [s_temp, un_temp] ,axis=1) 
    return  un_temp

# %% [markdown]
# Extracting Meaningful Values & Converting Binary(Meaningful & NaN)

# %%
def ext(data):
    cv = [] 
    for i in list(uvc(data).items()):
        for j in list(i)[1]: 
            if j not in nv:
                cv.append(j) 
    
    data = data.replace(cv,'M') 
    data = data.replace(nv,'NaN') 

    return data

# %% [markdown]
# ---
# ## Preprocessing 1.1
#
# Determining of Missing Values

# %% [markdown]
# ### `Check Unique Values to find NaN / Missing Values`

# %%
uvc(df)
# Out:
# defaultdict(None,
#             {'Ptid': array(['P1', 'P2', 'P3', ..., 'P3422', 'P3423', 'P3424'], dtype=object),
#              'Persistency_Flag': array(['Persistent', 'Non-Persistent'], dtype=object),
#              'Age_Bucket': array(['>75', '55-65', '65-75', '<55'], dtype=object),
#              'Race': array(['Caucasian', 'Asian', 'Other/Unknown', 'African American'],
#                    dtype=object),
#              'Region': array(['West', 'Midwest', 'South', 'Other/Unknown', 'Northeast'],
#                    dtype=object),
#              'Gender': array(['Male', 'Female'], dtype=object),
#              'Ethnicity': array(['Not Hispanic', 'Hispanic', 'Unknown'], dtype=object),
#              'Idn_Indicator': array(['N', 'Y'], dtype=object),
#              'Ntm_Speciality': array(['GENERAL PRACTITIONER', 'Unknown', 'ENDOCRINOLOGY', 'RHEUMATOLOGY',
#                     'ONCOLOGY', 'PATHOLOGY', 'OBSTETRICS AND GYNECOLOGY',
#                     'PSYCHIATRY AND NEUROLOGY', 'ORTHOPEDIC SURGERY',
#                     'PHYSICAL MEDICINE AND REHABILITATION',
#                     'SURGERY AND SURGICAL SPECIALTIES', 'PEDIATRICS',
#                     'PULMONARY MEDICINE', 'HEMATOLOGY & ONCOLOGY', 'UROLOGY',
#                     'PAIN MEDICINE', 'NEUROLOGY', 'RADIOLOGY', 'GASTROENTEROLOGY',
#                     'EMERGENCY MEDICINE', 'PODIATRY', 'OPHTHALMOLOGY',
#                     'OCCUPATIONAL MEDICINE', 'TRANSPLANT SURGERY', 'PLASTIC SURGERY',
#                     'CLINICAL NURSE SPECIALIST', 'OTOLARYNGOLOGY', 'HOSPITAL MEDICINE',
#                     'ORTHOPEDICS', 'NEPHROLOGY', 'GERIATRIC MEDICINE',
#                     'HOSPICE AND PALLIATIVE MEDICINE',
#                     'OBSTETRICS & OBSTETRICS & GYNECOLOGY & OBSTETRICS & GYNECOLOGY',
#                     'VASCULAR SURGERY', 'CARDIOLOGY', 'NUCLEAR MEDICINE'], dtype=object),
#              'Ntm_Specialist_Flag': array(['Others', 'Specialist'], dtype=object),
#              'Ntm_Speciality_Bucket': array(['OB/GYN/Others/PCP/Unknown', 'Endo/Onc/Uro', 'Rheum'], dtype=object),
#              'Tscore_Bucket_Prior_Ntm': array(['>-2.5', '<=-2.5'], dtype=object),
#              'Tscore_Bucket_During_Rx': array(['<=-2.5', 'Unknown', '>-2.5'], dtype=object),
#              'Change_T_Score': array(['No change', 'Unknown', 'Worsened', 'Improved'], dtype=object),
#              'Risk_Segment_Prior_Ntm': array(['VLR_LR', 'HR_VHR'], dtype=object),
#              'Risk_Segment_During_Rx': array(['VLR_LR', 'Unknown', 'HR_VHR'], dtype=object),
#              'Change_Risk_Segment': array(['Unknown', 'No change', 'Worsened', 'Improved'], dtype=object),
#              'Dexa_Freq_During_Rx': array([  0,   2,   7,   3,   5,  20,  13,   1,   6,  12,   4,  10,  25,
#                      11,  18,  21,  15,  28,  22,  37,  14,   8,   9,  17,  81,  42,
#                      16,  30,  19,  45,  27,  24,  58,  26,  23,  33, 110,  36,  34,
#                      88,  66,  32, 118,  48,  69,  38,  40,  68,  52,  50, 146,  44,
#                      35,  39, 108,  54,  72,  29]),
#              'Dexa_During_Rx': array(['N', 'Y'], dtype=object),
#              'Frag_Frac_Prior_Ntm': array(['N', 'Y'], dtype=object),
#              'Frag_Frac_During_Rx': array(['N', 'Y'], dtype=object),
#              'Gluco_Record_Prior_Ntm': array(['N', 'Y'], dtype=object),
#              'Gluco_Record_During_Rx': array(['N', 'Y'], dtype=object),
#              'Injectable_Experience_During_Rx': array(['Y', 'N'], dtype=object),
#              'Risk_Type_1_Insulin_Dependent_Diabetes': array(['N', 'Y'], dtype=object),
#              'Risk_Osteogenesis_Imperfecta': array(['N', 'Y'], dtype=object),
#              'Risk_Rheumatoid_Arthritis': array(['N', 'Y'], dtype=object),
#              'Risk_Untreated_Chronic_Hyperthyroidism': array(['N', 'Y'], dtype=object),
#              'Risk_Untreated_Chronic_Hypogonadism': array(['N', 'Y'], dtype=object),
#              'Risk_Untreated_Early_Menopause': array(['N', 'Y'], dtype=object),
#              'Risk_Patient_Parent_Fractured_Their_Hip': array(['N', 'Y'], dtype=object),
#              'Risk_Smoking_Tobacco': array(['N', 'Y'], dtype=object),
#              'Risk_Chronic_Malnutrition_Or_Malabsorption': array(['N', 'Y'], dtype=object),
#              'Risk_Chronic_Liver_Disease': array(['N', 'Y'], dtype=object),
#              'Risk_Family_History_Of_Osteoporosis': array(['N', 'Y'], dtype=object),
#              'Risk_Low_Calcium_Intake': array(['N', 'Y'], dtype=object),
#              'Risk_Vitamin_D_Insufficiency': array(['N', 'Y'], dtype=object),
#              'Risk_Poor_Health_Frailty': array(['N', 'Y'], dtype=object),
#              'Risk_Excessive_Thinness': array(['N', 'Y'], dtype=object),
#              'Risk_Hysterectomy_Oophorectomy': array(['N', 'Y'], dtype=object),
#              'Risk_Estrogen_Deficiency': array(['N', 'Y'], dtype=object),
#              'Risk_Immobilization': array(['N', 'Y'], dtype=object),
#              'Risk_Recurring_Falls': array(['N', 'Y'], dtype=object),
#              'Count_Of_Risks': array([0, 2, 1, 3, 4, 5, 6, 7]),
#              'Comorb_Encounter_For_Screening_For_Malignant_Neoplasms': array(['N', 'Y'], dtype=object),
#              'Comorb_Encounter_For_Immunization': array(['Y', 'N'], dtype=object),
#              'Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx': array(['Y', 'N'], dtype=object),
#              'Comorb_Vitamin_D_Deficiency': array(['N', 'Y'], dtype=object),
#              'Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified': array(['N', 'Y'], dtype=object),
#              'Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx': array(['Y', 'N'], dtype=object),
#              'Comorb_Long_Term_Current_Drug_Therapy': array(['N', 'Y'], dtype=object),
#              'Comorb_Dorsalgia': array(['Y', 'N'], dtype=object),
#              'Comorb_Personal_History_Of_Other_Diseases_And_Conditions': array(['Y', 'N'], dtype=object),
#              'Comorb_Other_Disorders_Of_Bone_Density_And_Structure': array(['N', 'Y'], dtype=object),
#              'Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias': array(['N', 'Y'], dtype=object),
#              'Comorb_Osteoporosis_without_current_pathological_fracture': array(['N', 'Y'], dtype=object),
#              'Comorb_Personal_history_of_malignant_neoplasm': array(['N', 'Y'], dtype=object),
#              'Comorb_Gastro_esophageal_reflux_disease': array(['N', 'Y'], dtype=object),
#              'Concom_Cholesterol_And_Triglyceride_Regulating_Preparations': array(['N', 'Y'], dtype=object),
#              'Concom_Narcotics': array(['N', 'Y'], dtype=object),
#              'Concom_Systemic_Corticosteroids_Plain': array(['N', 'Y'], dtype=object),
#              'Concom_Anti_Depressants_And_Mood_Stabilisers': array(['N', 'Y'], dtype=object),
#              'Concom_Fluoroquinolones': array(['N', 'Y'], dtype=object),
#              'Concom_Cephalosporins': array(['N', 'Y'], dtype=object),
#              'Concom_Macrolides_And_Similar_Types': array(['N', 'Y'], dtype=object),
#              'Concom_Broad_Spectrum_Penicillins': array(['N', 'Y'], dtype=object),
#              'Concom_Anaesthetics_General': array(['N', 'Y'], dtype=object),
#              'Concom_Viral_Vaccines': array(['N', 'Y'], dtype=object),
#              'Adherent_Flag': array(['Adherent', 'Non-Adherent'], dtype=object)})

# %% [markdown]
# `Define NaN / Missing Values`

# %%
nv = ['Other/Unknown', 'Unknown' ]

# %% [markdown]
# ---
# ## Preprocessing 1.2
#
# Investigation of Missing Values

# %% [markdown]
# ### Demographics & Target
#
# * `Persistency_Flag`,
# `Age`,
# `Race`,
# `Region`,
# `Ethnicity`,
# `Gender`,
# `IDN Indicator`,
# `NTM - Physician Specialty`

# %%
temp = pd.concat( [Target, Demographics,Provider],axis=1)

# %% [markdown]
# Datafreme of Unique & Missing Values

# %%
print('Number of Rows:',len(temp)) 
print('Number of Columns:',len(temp.columns)) 
un( ext(temp) ).T.head(1+len(temp.columns)).T
# Out:
# Number of Rows: 3424
# Number of Columns: 10
#                Sum  Persistency_Flag  Age_Bucket  Race  Region  Gender  \
# Unique Values   14                 1           1     2       2       1
# Nan Values     558                 0           0    97      60       0
#
#                Ethnicity  Idn_Indicator  Ntm_Speciality  Ntm_Specialist_Flag  \
# Unique Values          2              1               2                    1
# Nan Values            91              0             310                    0
#
#                Ntm_Speciality_Bucket
# Unique Values                      1
# Nan Values                         0

# %%
print('Number of Rows:',len(df2)) 
print('Number of Columns:',len(df2.columns)) 
un( ext(df2) ).T.head(1+len(df2.columns)).T
# Out:
# Number of Rows: 3424
# Number of Columns: 69
#                 Sum  Ptid  Persistency_Flag  Gender  Race  Ethnicity  Region  \
# Unique Values    77     1                 1       1     2          2       2
# Nan Values     7278     0                 0       0    97         91      60
#
#                Age_Bucket  Ntm_Speciality  Ntm_Specialist_Flag  ...  \
# Unique Values           1               2                    1  ...
# Nan Values              0             310                    0  ...
#
#                Risk_Family_History_Of_Osteoporosis  Risk_Low_Calcium_Intake  \
# Unique Values                                    1                        1
# Nan Values                                       0                        0
#
#                Risk_Vitamin_D_Insufficiency  Risk_Poor_Health_Frailty  \
# Unique Values                             1                         1
# Nan Values                                0                         0
#
#                Risk_Excessive_Thinness  Risk_Hysterectomy_Oophorectomy  \
# Unique Values                        1                               1
# Nan Values                           0                               0
#
#                Risk_Estrogen_Deficiency  Risk_Immobilization  \
# Unique Values                         1                    1
# Nan Values                            0                    0
#
#                Risk_Recurring_Falls  Count_Of_Risks
# Unique Values                     1               1
# Nan Values                        0               0
#
# [2 rows x 70 columns]

# %% [markdown]
# ### Clinical
# `NTM - T-Score `,
# `Change in T Score `,
# `NTM - Risk Segment`,
# `Change in Risk Segment`,
# `NTM - Multiple Risk Factors` ,
# `NTM - Dexa Scan Frequency`,
# `NTM - Dexa Scan Recency` ,
# `Dexa During Therapy` ,
# `NTM - Fragility Fracture Recency`,
# `Fragility Fracture During Therapy` ,
# `NTM - Glucocorticoid Recency` ,
# `Glucocorticoid Usage During Therapy`

# %%
temp = Clinical.copy()

# %%
print('Number of Rows:',len(temp)) 
print('Number of Columns:',len(temp.columns)) 
un( ext(temp) ).T.head(1+len(temp.columns)).T
# Out:
# Number of Rows: 3424
# Number of Columns: 12
#                 Sum  Tscore_Bucket_Prior_Ntm  Tscore_Bucket_During_Rx  \
# Unique Values    16                        1                        2
# Nan Values     6720                        0                     1497
#
#                Change_T_Score  Risk_Segment_Prior_Ntm  Risk_Segment_During_Rx  \
# Unique Values               2                       1                       2
# Nan Values               1497                       0                    1497
#
#                Change_Risk_Segment  Dexa_Freq_During_Rx  Dexa_During_Rx  \
# Unique Values                    2                    1               1
# Nan Values                    2229                    0               0
#
#                Frag_Frac_Prior_Ntm  Frag_Frac_During_Rx  \
# Unique Values                    1                    1
# Nan Values                       0                    0
#
#                Gluco_Record_Prior_Ntm  Gluco_Record_During_Rx
# Unique Values                       1                       1
# Nan Values                          0                       0

# %% [markdown]
# ### Disease/Treatment Factor
#
# * `NTM - Injectable Experience`, `NTM - Comorbidity`, `NTM - Concomitancy`, `NTM - Risk Factors`, `Adherence`

# %%
temp = pd.concat([ntm_i, r_f ,ad],axis=1)

# %%
print('Number of Rows:',len(temp)) 
print('Number of Columns:',len(temp.columns)) 
un( ext(temp) ).T.head(1+len(temp.columns)).T
# Out:
# Number of Rows: 3424
# Number of Columns: 22
#                Sum  Injectable_Experience_During_Rx  \
# Unique Values   22                                1
# Nan Values       0                                0
#
#                Risk_Type_1_Insulin_Dependent_Diabetes  \
# Unique Values                                       1
# Nan Values                                          0
#
#                Risk_Osteogenesis_Imperfecta  Risk_Rheumatoid_Arthritis  \
# Unique Values                             1                          1
# Nan Values                                0                          0
#
#                Risk_Untreated_Chronic_Hyperthyroidism  \
# Unique Values                                       1
# Nan Values                                          0
#
#                Risk_Untreated_Chronic_Hypogonadism  \
# Unique Values                                    1
# Nan Values                                       0
#
#                Risk_Untreated_Early_Menopause  \
# Unique Values                               1
# Nan Values                                  0
#
#                Risk_Patient_Parent_Fractured_Their_Hip  Risk_Smoking_Tobacco  \
# Unique Values                                        1                     1
# Nan Values                                           0                     0
#
#                ...  Risk_Low_Calcium_Intake  Risk_Vitamin_D_Insufficiency  \
# Unique Values  ...                        1                             1
# Nan Values     ...                        0                             0
#
#                Risk_Poor_Health_Frailty  Risk_Excessive_Thinness  \
# Unique Values                         1                        1
# Nan Values                            0                        0
#
#                Risk_Hysterectomy_Oophorectomy  Risk_Estrogen_Deficiency  \
# Unique Values                               1                         1
# Nan Values                                  0                         0
#
#                Risk_Immobilization  Risk_Recurring_Falls  Count_Of_Risks  \
# Unique Values                    1                     1               1
# Nan Values                       0                     0               0
#
#                Adherent_Flag
# Unique Values              1
# Nan Values                 0
#
# [2 rows x 23 columns]

# %% [markdown]
# `NTM - Comorbidity `

# %%
temp = ntm_com

# %%
print('Number of Rows:',len(temp)) 
print('Number of Columns:',len(temp.columns)) 
un( ext(temp) ).T.head(1+len(temp.columns)).T
# Out:
# Number of Rows: 3424
# Number of Columns: 14
#                Sum  Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# Unique Values   14                                                  1
# Nan Values       0                                                  0
#
#                Comorb_Encounter_For_Immunization  \
# Unique Values                                  1
# Nan Values                                     0
#
#                Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Vitamin_D_Deficiency  \
# Unique Values                            1
# Nan Values                               0
#
#                Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Long_Term_Current_Drug_Therapy  Comorb_Dorsalgia  \
# Unique Values                                      1                 1
# Nan Values                                         0                 0
#
#                Comorb_Personal_History_Of_Other_Diseases_And_Conditions  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Other_Disorders_Of_Bone_Density_And_Structure  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Osteoporosis_without_current_pathological_fracture  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Comorb_Personal_history_of_malignant_neoplasm  \
# Unique Values                                              1
# Nan Values                                                 0
#
#                Comorb_Gastro_esophageal_reflux_disease
# Unique Values                                        1
# Nan Values                                           0

# %% [markdown]
# `NTM - Concomitancy
# `

# %%
temp = ntm_con

# %%
print('Number of Rows:',len(temp)) 
print('Number of Columns:',len(temp.columns)) 
un( ext(temp) ).T.head(1+len(temp.columns)).T
# Out:
# Number of Rows: 3424
# Number of Columns: 10
#                Sum  \
# Unique Values   10
# Nan Values       0
#
#                Concom_Cholesterol_And_Triglyceride_Regulating_Preparations  \
# Unique Values                                                  1
# Nan Values                                                     0
#
#                Concom_Narcotics  Concom_Systemic_Corticosteroids_Plain  \
# Unique Values                 1                                      1
# Nan Values                    0                                      0
#
#                Concom_Anti_Depressants_And_Mood_Stabilisers  \
# Unique Values                                             1
# Nan Values                                                0
#
#                Concom_Fluoroquinolones  Concom_Cephalosporins  \
# Unique Values                        1                      1
# Nan Values                           0                      0
#
#                Concom_Macrolides_And_Similar_Types  \
# Unique Values                                    1
# Nan Values                                       0
#
#                Concom_Broad_Spectrum_Penicillins  Concom_Anaesthetics_General  \
# Unique Values                                  1                            1
# Nan Values                                     0                            0
#
#                Concom_Viral_Vaccines
# Unique Values                      1
# Nan Values                         0

# %% [markdown]
# ---
# ## Preprocessing 1.3.0
# Extraction of NaN Values

# %%
df_view = un( ext(df) ).T.head(1+len(df.columns))

# %% [markdown]
# Check in the editor

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(df_view)
# Out:
#                                                     Unique Values  Nan Values
# Sum                                                            77        7278
# Ptid                                                            1           0
# Persistency_Flag                                                1           0
# Age_Bucket                                                      1           0
# Race                                                            2          97
# Region                                                          2          60
# Gender                                                          1           0
# Ethnicity                                                       2          91
# Idn_Indicator                                                   1           0
# Ntm_Speciality                                                  2         310
# Ntm_Specialist_Flag                                             1           0
# Ntm_Speciality_Bucket                                           1           0
# Tscore_Bucket_Prior_Ntm                                         1           0
# Tscore_Bucket_During_Rx                                         2        1497
# Change_T_Score                                                  2        1497
# Risk_Segment_Prior_Ntm                                          1           0
# Risk_Segment_During_Rx                                          2        1497
# Change_Risk_Segment                                             2        2229
# Dexa_Freq_During_Rx                                             1           0
# Dexa_During_Rx                                                  1           0
# Frag_Frac_Prior_Ntm                                             1           0
# Frag_Frac_During_Rx                                             1           0
# Gluco_Record_Prior_Ntm                                          1           0
# Gluco_Record_During_Rx                                          1           0
# Injectable_Experience_During_Rx                                 1           0
# Risk_Type_1_Insulin_Dependent_Diabetes                          1           0
# Risk_Osteogenesis_Imperfecta                                    1           0
# Risk_Rheumatoid_Arthritis                                       1           0
# Risk_Untreated_Chronic_Hyperthyroidism                          1           0
# Risk_Untreated_Chronic_Hypogonadism                             1           0
# Risk_Untreated_Early_Menopause                                  1           0
# Risk_Patient_Parent_Fractured_Their_Hip                         1           0
# Risk_Smoking_Tobacco                                            1           0
# Risk_Chronic_Malnutrition_Or_Malabsorption                      1           0
# Risk_Chronic_Liver_Disease                                      1           0
# Risk_Family_History_Of_Osteoporosis                             1           0
# Risk_Low_Calcium_Intake                                         1           0
# Risk_Vitamin_D_Insufficiency                                    1           0
# Risk_Poor_Health_Frailty                                        1           0
# Risk_Excessive_Thinness                                         1           0
# Risk_Hysterectomy_Oophorectomy                                  1           0
# Risk_Estrogen_Deficiency                                        1           0
# Risk_Immobilization                                             1           0
# Risk_Recurring_Falls                                            1           0
# Count_Of_Risks                                                  1           0
# Comorb_Encounter_For_Screening_For_Malignant_Ne...              1           0
# Comorb_Encounter_For_Immunization                               1           0
# Comorb_Encntr_For_General_Exam_W_O_Complaint,_S...              1           0
# Comorb_Vitamin_D_Deficiency                                     1           0
# Comorb_Other_Joint_Disorder_Not_Elsewhere_Class...              1           0
# Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Sus...              1           0
# Comorb_Long_Term_Current_Drug_Therapy                           1           0
# Comorb_Dorsalgia                                                1           0
# Comorb_Personal_History_Of_Other_Diseases_And_C...              1           0
# Comorb_Other_Disorders_Of_Bone_Density_And_Stru...              1           0
# Comorb_Disorders_of_lipoprotein_metabolism_and_...              1           0
# Comorb_Osteoporosis_without_current_pathologica...              1           0
# Comorb_Personal_history_of_malignant_neoplasm                   1           0
# Comorb_Gastro_esophageal_reflux_disease                         1           0
# Concom_Cholesterol_And_Triglyceride_Regulating_...              1           0
# Concom_Narcotics                                                1           0
# Concom_Systemic_Corticosteroids_Plain                           1           0
# Concom_Anti_Depressants_And_Mood_Stabilisers                    1           0
# Concom_Fluoroquinolones                                         1           0
# Concom_Cephalosporins                                           1           0
# Concom_Macrolides_And_Similar_Types                             1           0
# Concom_Broad_Spectrum_Penicillins                               1           0
# Concom_Anaesthetics_General                                     1           0
# Concom_Viral_Vaccines                                           1           0
# Adherent_Flag                                                   1           0

# %% [markdown]
# ---
# ## Preprocessing 1.3.1
#
# Drop Operations

# %%
temp = df.copy()

# %%
# Drop Values  
will_drop = nv 

# Columns to be ignored for checking 
ignore_col = ['Change_Risk_Segment', 'Change_T_Score','Tscore_Bucket_During_Rx','Risk_Segment_During_Rx'] 

# Columns to be checked
temp_col = [] 
for i in list(temp.columns):
    if i not in ignore_col:
        temp_col.append(i) 

# Drop rows that contain any value in the list, will_drop
for i in temp_col:
    temp = temp[ temp[i].isin(will_drop) == False ]

# %% [markdown]
# ---
# # Preprocess Part 1 Result
# NaN & Unique Value Extraction

# %%
print('Number of Rows of Raw Data:', len(df)) 
print('Number of Rows of Raw Data:', len(temp)) 
print('Number of Dropped Values:', (len(df) - len(temp)) )
# Out:
# Number of Rows of Raw Data: 3424
# Number of Rows of Raw Data: 2912
# Number of Dropped Values: 512

# %%
df = temp

# %% [markdown]
# ---
# ---
# # Preprocess Part 2

# %% [markdown]
# ### Model Development

# %%
df.head(2).T
# Out:
#                                               0               1
# Ptid                                         P1              P2
# Persistency_Flag                     Persistent  Non-Persistent
# Age_Bucket                                  >75           55-65
# Race                                  Caucasian           Asian
# Region                                     West            West
# ...                                         ...             ...
# Concom_Macrolides_And_Similar_Types           N               N
# Concom_Broad_Spectrum_Penicillins             N               N
# Concom_Anaesthetics_General                   N               N
# Concom_Viral_Vaccines                         N               N
# Adherent_Flag                          Adherent        Adherent
#
# [69 rows x 2 columns]
